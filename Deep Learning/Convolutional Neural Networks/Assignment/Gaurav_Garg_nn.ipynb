# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=batch_size, 
                                                            image_size=(img_height,img_width),seed=123,
                                                            validation_split=0.2,subset='training')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=batch_size, 
                                                            image_size=(img_height,img_width),seed=123,
                                                            validation_split=0.2,subset='validation')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
num_classes=9

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 706s 3s/step - loss: 2.0976 - accuracy: 0.2644 - val_loss: 1.6608 - val_accuracy: 0.4072
# Epoch 2/20
# 56/56 [==============================] - 54s 972ms/step - loss: 1.5724 - accuracy: 0.4319 - val_loss: 1.4655 - val_accuracy: 0.4899
# Epoch 3/20
# 56/56 [==============================] - 54s 965ms/step - loss: 1.4302 - accuracy: 0.5027 - val_loss: 1.4243 - val_accuracy: 0.5168
# Epoch 4/20
# 56/56 [==============================] - 54s 966ms/step - loss: 1.2862 - accuracy: 0.5456 - val_loss: 1.3359 - val_accuracy: 0.5347
# Epoch 5/20
# 56/56 [==============================] - 58s 1s/step - loss: 1.1931 - accuracy: 0.5825 - val_loss: 1.3672 - val_accuracy: 0.5280
# Epoch 6/20
# 56/56 [==============================] - 54s 966ms/step - loss: 1.1943 - accuracy: 0.5761 - val_loss: 1.3211 - val_accuracy: 0.5705
# Epoch 7/20
# 56/56 [==============================] - 54s 967ms/step - loss: 1.0610 - accuracy: 0.6300 - val_loss: 1.3185 - val_accuracy: 0.5459
# Epoch 8/20
# 56/56 [==============================] - 54s 972ms/step - loss: 0.9502 - accuracy: 0.6424 - val_loss: 1.3446 - val_accuracy: 0.5481
# Epoch 9/20
# 56/56 [==============================] - 54s 972ms/step - loss: 0.8993 - accuracy: 0.6864 - val_loss: 1.4457 - val_accuracy: 0.5570
# Epoch 10/20
# 56/56 [==============================] - 55s 975ms/step - loss: 0.8182 - accuracy: 0.7028 - val_loss: 1.4986 - val_accuracy: 0.5257
# Epoch 11/20
# 56/56 [==============================] - 54s 974ms/step - loss: 0.7311 - accuracy: 0.7314 - val_loss: 1.5982 - val_accuracy: 0.5459
# Epoch 12/20
# 56/56 [==============================] - 54s 971ms/step - loss: 0.6258 - accuracy: 0.7771 - val_loss: 1.7026 - val_accuracy: 0.5056
# Epoch 13/20
# 56/56 [==============================] - 55s 975ms/step - loss: 0.6261 - accuracy: 0.7548 - val_loss: 1.9549 - val_accuracy: 0.5570
# Epoch 14/20
# 56/56 [==============================] - 54s 974ms/step - loss: 0.4630 - accuracy: 0.8404 - val_loss: 1.6935 - val_accuracy: 0.5436
# Epoch 15/20
# 56/56 [==============================] - 55s 975ms/step - loss: 0.3782 - accuracy: 0.8638 - val_loss: 1.7947 - val_accuracy: 0.5056
# Epoch 16/20
# 56/56 [==============================] - 59s 1s/step - loss: 0.3686 - accuracy: 0.8802 - val_loss: 1.8751 - val_accuracy: 0.4810
# Epoch 17/20
# 56/56 [==============================] - 54s 961ms/step - loss: 0.3242 - accuracy: 0.8850 - val_loss: 2.0369 - val_accuracy: 0.5436
# Epoch 18/20
# 56/56 [==============================] - 54s 966ms/step - loss: 0.2778 - accuracy: 0.9020 - val_loss: 2.0451 - val_accuracy: 0.5459
# Epoch 19/20
# 56/56 [==============================] - 54s 964ms/step - loss: 0.1962 - accuracy: 0.9302 - val_loss: 2.2494 - val_accuracy: 0.5347
# Epoch 20/20
# 56/56 [==============================] - 54s 966ms/step - loss: 0.1963 - accuracy: 0.9210 - val_loss: 2.1991 - val_accuracy: 0.5481

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or **underfit**

# %% [markdown]
# ### Write your findings here
# 1. Model seems to be Overfitting since there is a huge difference beween training and validation accuracy.
# 2. Dropouts layers can be added to prevent overfitting

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

data_aug = Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2,fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom((0.2,0.3), fill_mode='reflect')])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    augmented = data_aug(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
num_classes = 9

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  data_aug,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_3 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 65s 1s/step - loss: 2.1963 - accuracy: 0.1909 - val_loss: 1.7949 - val_accuracy: 0.3512
# Epoch 2/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.7741 - accuracy: 0.3620 - val_loss: 1.5918 - val_accuracy: 0.4251
# Epoch 3/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.5517 - accuracy: 0.4452 - val_loss: 1.4491 - val_accuracy: 0.5078
# Epoch 4/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.4243 - accuracy: 0.5025 - val_loss: 1.4390 - val_accuracy: 0.5235
# Epoch 5/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.3727 - accuracy: 0.5121 - val_loss: 1.4725 - val_accuracy: 0.4720
# Epoch 6/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.3612 - accuracy: 0.5163 - val_loss: 1.3857 - val_accuracy: 0.5347
# Epoch 7/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.3446 - accuracy: 0.5258 - val_loss: 1.3868 - val_accuracy: 0.5302
# Epoch 8/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.2726 - accuracy: 0.5485 - val_loss: 1.3720 - val_accuracy: 0.5302
# Epoch 9/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.2380 - accuracy: 0.5561 - val_loss: 1.4104 - val_accuracy: 0.5011
# Epoch 10/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.2895 - accuracy: 0.5453 - val_loss: 1.3913 - val_accuracy: 0.5302
# Epoch 11/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.2189 - accuracy: 0.5800 - val_loss: 1.4182 - val_accuracy: 0.5123
# Epoch 12/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.2916 - accuracy: 0.5329 - val_loss: 1.4833 - val_accuracy: 0.4810
# Epoch 13/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.1941 - accuracy: 0.5707 - val_loss: 1.4014 - val_accuracy: 0.5078
# Epoch 14/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.1853 - accuracy: 0.5569 - val_loss: 1.3113 - val_accuracy: 0.5593
# Epoch 15/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.1621 - accuracy: 0.5710 - val_loss: 1.3267 - val_accuracy: 0.5235
# Epoch 16/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.1591 - accuracy: 0.5942 - val_loss: 1.4212 - val_accuracy: 0.5145
# Epoch 17/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.1278 - accuracy: 0.5862 - val_loss: 1.3588 - val_accuracy: 0.5459
# Epoch 18/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.0896 - accuracy: 0.6138 - val_loss: 1.3133 - val_accuracy: 0.5280
# Epoch 19/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.1809 - accuracy: 0.5791 - val_loss: 1.3625 - val_accuracy: 0.5615
# Epoch 20/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.0925 - accuracy: 0.6123 - val_loss: 1.3220 - val_accuracy: 0.5280

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# 1. The **overfitting** in the model is now gone since we used dropout layers. But still the performance is bad since accuracy for validation 0.56 max.
# 2. Model is **underfitting** since performance/accuracy is very low on training as well as validation set.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
import glob
path_list = [x for x in glob.glob(os.path.join(data_dir_train, '*','*.jpg'))]
label_list = [os.path.basename(os.path.dirname(y)) for y in glob.glob(os.path.join(data_dir_train, '*', '*.jpg'))]
dataframe_dict_new = dict(zip(path_list, label_list))
df_label = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
class_dist = df_label['Label'].value_counts()
class_dist
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# Ans - seborrheic keratosis has 77 samples which is least in training dataset
# #### - Which classes dominate the data in terms proportionate number of samples?
# Ans -  pigmented benign keratosis with 462 samples in training dataset

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.8)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.19.5)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.0.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.41.1)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F336FFA9AD0>:   0%|          | 1/500 [00:00<01:31,  5.45 Samples/s]
# Initialised with 114 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F336FF78B90>: 100%|██████████| 500/500 [00:22<00:00, 21.77 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F336C1533D0>: 100%|██████████| 500/500 [00:23<00:00, 21.62 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F336B8D6550>: 100%|██████████| 500/500 [00:23<00:00, 21.00 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x576 at 0x7F336FF78A10>: 100%|██████████| 500/500 [01:41<00:00,  4.95 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F336C1AEA90>: 100%|██████████| 500/500 [01:35<00:00,  5.26 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F336B8EF6D0>: 100%|██████████| 500/500 [00:22<00:00, 21.85 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F336FF5AD90>: 100%|██████████| 500/500 [00:51<00:00,  9.79 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F336FF9EF50>: 100%|██████████| 500/500 [00:22<00:00, 22.52 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F336B8CC410>: 100%|██████████| 500/500 [00:22<00:00, 22.64 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])

# %%
df2['Label'].value_counts()
# Out:
# vascular lesion               500
# actinic keratosis             500
# melanoma                      500
# pigmented benign keratosis    500
# nevus                         500
# seborrheic keratosis          500
# dermatofibroma                500
# squamous cell carcinoma       500
# basal cell carcinoma          500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="gdrive/My Drive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
num_classes = 9

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_height,img_width,3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_5 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 30 epochs.
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 4308s 25s/step - loss: 2.1433 - accuracy: 0.1907 - val_loss: 1.5474 - val_accuracy: 0.4135
# Epoch 2/30
# 169/169 [==============================] - 205s 1s/step - loss: 1.4377 - accuracy: 0.4569 - val_loss: 1.2834 - val_accuracy: 0.5375
# Epoch 3/30
# 169/169 [==============================] - 203s 1s/step - loss: 1.2215 - accuracy: 0.5362 - val_loss: 1.2030 - val_accuracy: 0.5694
# Epoch 4/30
# 169/169 [==============================] - 203s 1s/step - loss: 1.0781 - accuracy: 0.6072 - val_loss: 1.0373 - val_accuracy: 0.6414
# Epoch 5/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.9145 - accuracy: 0.6586 - val_loss: 0.9949 - val_accuracy: 0.6719
# Epoch 6/30
# 169/169 [==============================] - 202s 1s/step - loss: 0.7786 - accuracy: 0.7208 - val_loss: 0.9188 - val_accuracy: 0.6964
# Epoch 7/30
# 169/169 [==============================] - 202s 1s/step - loss: 0.6457 - accuracy: 0.7733 - val_loss: 0.9872 - val_accuracy: 0.6696
# Epoch 8/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.5390 - accuracy: 0.8043 - val_loss: 0.8572 - val_accuracy: 0.7446
# Epoch 9/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.4457 - accuracy: 0.8393 - val_loss: 1.0159 - val_accuracy: 0.6889
# Epoch 10/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.4133 - accuracy: 0.8530 - val_loss: 0.9268 - val_accuracy: 0.7327
# Epoch 11/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.3821 - accuracy: 0.8621 - val_loss: 0.7754 - val_accuracy: 0.7958
# Epoch 12/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.3432 - accuracy: 0.8724 - val_loss: 0.7746 - val_accuracy: 0.7921
# Epoch 13/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.2585 - accuracy: 0.9005 - val_loss: 0.8146 - val_accuracy: 0.7706
# Epoch 14/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.2661 - accuracy: 0.8988 - val_loss: 0.7660 - val_accuracy: 0.8203
# Epoch 15/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.2073 - accuracy: 0.9199 - val_loss: 0.7792 - val_accuracy: 0.8018
# Epoch 16/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.2830 - accuracy: 0.8866 - val_loss: 0.8055 - val_accuracy: 0.8048
# Epoch 17/30
# 169/169 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.9067Epoch 18/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.1986 - accuracy: 0.9256 - val_loss: 0.8263 - val_accuracy: 0.8018
# Epoch 19/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.1901 - accuracy: 0.9273 - val_loss: 0.8055 - val_accuracy: 0.8114
# Epoch 20/30
# 169/169 [==============================] - 205s 1s/step - loss: 0.1807 - accuracy: 0.9299 - val_loss: 0.9180 - val_accuracy: 0.8107
# Epoch 21/30
# 169/169 [==============================] - 207s 1s/step - loss: 0.1858 - accuracy: 0.9269 - val_loss: 0.8584 - val_accuracy: 0.8181
# Epoch 22/30
# 169/169 [==============================] - 206s 1s/step - loss: 0.2170 - accuracy: 0.9259 - val_loss: 0.9387 - val_accuracy: 0.8151
# Epoch 23/30
# 169/169 [==============================] - 205s 1s/step - loss: 0.1696 - accuracy: 0.9280 - val_loss: 0.9510 - val_accuracy: 0.8077
# Epoch 24/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.1636 - accuracy: 0.9347 - val_loss: 0.9089 - val_accuracy: 0.8144
# Epoch 25/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.1750 - accuracy: 0.9296 - val_loss: 1.0825 - val_accuracy: 0.8159
# Epoch 26/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.2196 - accuracy: 0.9161 - val_loss: 0.9569 - val_accuracy: 0.8055
# Epoch 27/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.1643 - accuracy: 0.9358 - val_loss: 0.9221 - val_accuracy: 0.8322
# Epoch 28/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.1383 - accuracy: 0.9409 - val_loss: 0.8979 - val_accuracy: 0.8189
# Epoch 29/30
# 169/169 [==============================] - 204s 1s/step - loss: 0.1337 - accuracy: 0.9415 - val_loss: 1.0547 - val_accuracy: 0.8233
# Epoch 30/30
# 169/169 [==============================] - 203s 1s/step - loss: 0.1241 - accuracy: 0.9482 - val_loss: 0.9717 - val_accuracy: 0.8248

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# 1. Class Rebalance using Agmentor improved the accuracy, we get maximum 0.83 accuracy on validation set
# 2. Underfitting is reduced since we no longer have low performance
# 3. Overfitting is handled using Dropout layers
